# %% [markdown]
# # DataFrame

# %% [markdown]
# DataFrame is probably the most important and most commonly used object in pandas. A DataFrame is basically a collection of a number of Series that share common indices. A DataFrame arranges data in rows and columns in a tabular structure. For an indepth study of DataFrames see [this tutorial](https://www.datacamp.com/community/tutorials/pandas-tutorial-dataframe-python) from datacamp.

# %%
import pandas as pd

# %% [markdown]
# With the import in place, let's now define the problem we are going to solve using DataFrame.

# %% [markdown]
# ## Problem 1

# %% [markdown]
# You are given the heights (in inch) and weights (in lbs) of 5 people as shown in the table below:

# %% [markdown]
# | Person | Height(inch) | Weight(lbs) |
# |--------|--------------|-------------|
# |    A   |     72       |      186    |
# |    B   |     69       |      205    |
# |    C   |     70       |      201    |
# |    D   |     62       |      125    |
# |    E   |     57       |      89     |

# %% [markdown]
# It is later found that the table actually misses entries for persons F and G whose heights are 65 inch and 60 inch respectively and the weight for F is 121 lbs, but data for G's weight is missing. Also, values for all the heights is found to be 5 inch less than it should have been, whereas values for all the weights is found to be 5 lbs more than it should have been. Find the correct Body Mass Index (BMI) for each person, if possible.

# %%
height_weight_df = pd.DataFrame(data=[['A',72,186],['B',69,205],['C',70,201],['D',62,125],['E',57,89]], columns=['Person','Height','Weight'])

# %%
height_weight_df.head(n=3)
# Out:
#   Person  Height  Weight
# 0      A      72     186
# 1      B      69     205
# 2      C      70     201

# %%
height_weight_df.describe()
# Out:
#           Height      Weight
# count   5.000000    5.000000
# mean   66.000000  161.200000
# std     6.284903   51.577127
# min    57.000000   89.000000
# 25%    62.000000  125.000000
# 50%    69.000000  186.000000
# 75%    70.000000  201.000000
# max    72.000000  205.000000

# %%
height_weight_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
# Person    5 non-null object
# Height    5 non-null int64
# Weight    5 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 200.0+ bytes

# %%
height_weight_df.set_index(['Person'])
# Out:
#         Height  Weight
# Person
# A           72     186
# B           69     205
# C           70     201
# D           62     125
# E           57      89

# %%
height_weight_df.set_index(['Person'],inplace=True)

# %%
height_weight_df
# Out:
#         Height  Weight
# Person
# A           72     186
# B           69     205
# C           70     201
# D           62     125
# E           57      89

# %%
height_weight_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, A to E
# Data columns (total 2 columns):
# Height    5 non-null int64
# Weight    5 non-null int64
# dtypes: int64(2)
# memory usage: 120.0+ bytes

# %%
height_weight_df['Height']
# Out:
# Person
# A    72
# B    69
# C    70
# D    62
# E    57
# Name: Height, dtype: int64

# %%
height_weight_df['Weight']
# Out:
# Person
# A    186
# B    205
# C    201
# D    125
# E     89
# Name: Weight, dtype: int64

# %%
type(height_weight_df['Height'])
# Out:
# pandas.core.series.Series

# %%
missing_df = pd.DataFrame(data=[[65,121],[60]],index=['F','G'],columns=['Height','Weight'])

# %%
missing_df
# Out:
#    Height  Weight
# F      65   121.0
# G      60     NaN

# %%
updated_df = height_weight_df.append(missing_df)
updated_df
# Out:
#    Height  Weight
# A      72   186.0
# B      69   205.0
# C      70   201.0
# D      62   125.0
# E      57    89.0
# F      65   121.0
# G      60     NaN

# %%
updated_df['Height'] += 5
updated_df['Weight'] -=5

# %%
updated_df
# Out:
#    Height  Weight
# A      77   181.0
# B      74   200.0
# C      75   196.0
# D      67   120.0
# E      62    84.0
# F      70   116.0
# G      65     NaN

# %%
updated_df.fillna(updated_df.mean())
# Out:
#    Height  Weight
# A      77   181.0
# B      74   200.0
# C      75   196.0
# D      67   120.0
# E      62    84.0
# F      70   116.0
# G      65   149.5

# %%
updated_df
# Out:
#    Height  Weight
# A      77   181.0
# B      74   200.0
# C      75   196.0
# D      67   120.0
# E      62    84.0
# F      70   116.0
# G      65     NaN

# %%
updated_df.dropna(inplace=True)

# %%
updated_df
# Out:
#    Height  Weight
# A      77   181.0
# B      74   200.0
# C      75   196.0
# D      67   120.0
# E      62    84.0
# F      70   116.0

# %%
lbs_to_kg_ratio = 0.453592
inch_to_meter_ratio = 0.0254

# %%
updated_df['Height'] *= inch_to_meter_ratio
updated_df['Weight'] *= lbs_to_kg_ratio

# %%
updated_df
# Out:
#    Height     Weight
# A  1.9558  82.100152
# B  1.8796  90.718400
# C  1.9050  88.904032
# D  1.7018  54.431040
# E  1.5748  38.101728
# F  1.7780  52.616672

# %%
updated_df['BMI'] = updated_df['Weight']/(updated_df['Height']**2)

# %%
updated_df
# Out:
#    Height     Weight        BMI
# A  1.9558  82.100152  21.463230
# B  1.8796  90.718400  25.678196
# C  1.9050  88.904032  24.498049
# D  1.7018  54.431040  18.794449
# E  1.5748  38.101728  15.363631
# F  1.7780  52.616672  16.644083

# %%
updated_df.to_csv('BMI.csv',index_label='Person')

# %% [markdown]
# ## Problem 2

# %%
travel_df = pd.read_csv('travel-times.csv')

# %%
travel_df.head()
# Out:
#        Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0  1/6/2012     16:37     Friday    Home     51.29     127.4      78.3
# 1  1/6/2012     08:20     Friday     GSK     51.63     130.3      81.8
# 2  1/4/2012     16:17  Wednesday    Home     51.27     127.4      82.0
# 3  1/4/2012     07:53  Wednesday     GSK     49.17     132.3      74.2
# 4  1/3/2012     18:57    Tuesday    Home     51.15     136.2      83.4
#
#    AvgMovingSpeed FuelEconomy  TotalTime  MovingTime Take407All Comments
# 0            84.8         NaN       39.3        36.3         No      NaN
# 1            88.9         NaN       37.9        34.9         No      NaN
# 2            85.8         NaN       37.5        35.9         No      NaN
# 3            82.9         NaN       39.8        35.6         No      NaN
# 4            88.1         NaN       36.8        34.8         No      NaN

# %%
travel_df.describe()
# Out:
#          Distance    MaxSpeed    AvgSpeed  AvgMovingSpeed   TotalTime  \
# count  205.000000  205.000000  205.000000      205.000000  205.000000
# mean    50.981512  127.591707   74.477561       81.975610   41.904390
# std      1.321205    4.128450   11.409816       10.111544    6.849476
# min     48.320000  112.200000   38.100000       50.300000   28.200000
# 25%     50.650000  124.900000   68.900000       76.600000   38.400000
# 50%     51.140000  127.400000   73.600000       81.400000   41.300000
# 75%     51.630000  129.800000   79.900000       86.000000   44.400000
# max     60.320000  140.900000  107.700000      112.100000   82.300000
#
#        MovingTime
# count  205.000000
# mean    37.871707
# std      4.835072
# min     27.100000
# 25%     35.700000
# 50%     37.600000
# 75%     39.900000
# max     62.400000

# %%
travel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 13 columns):
# Date              205 non-null object
# StartTime         205 non-null object
# DayOfWeek         205 non-null object
# GoingTo           205 non-null object
# Distance          205 non-null float64
# MaxSpeed          205 non-null float64
# AvgSpeed          205 non-null float64
# AvgMovingSpeed    205 non-null float64
# FuelEconomy       188 non-null object
# TotalTime         205 non-null float64
# MovingTime        205 non-null float64
# Take407All        205 non-null object
# Comments          24 non-null object
# dtypes: float64(6), object(7)
# memory usage: 20.9+ KB

# %%
travel_df.drop(labels=['Comments'],axis=1,inplace=True)

# %%
travel_df.head()
# Out:
#        Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0  1/6/2012     16:37     Friday    Home     51.29     127.4      78.3
# 1  1/6/2012     08:20     Friday     GSK     51.63     130.3      81.8
# 2  1/4/2012     16:17  Wednesday    Home     51.27     127.4      82.0
# 3  1/4/2012     07:53  Wednesday     GSK     49.17     132.3      74.2
# 4  1/3/2012     18:57    Tuesday    Home     51.15     136.2      83.4
#
#    AvgMovingSpeed FuelEconomy  TotalTime  MovingTime Take407All
# 0            84.8         NaN       39.3        36.3         No
# 1            88.9         NaN       37.9        34.9         No
# 2            85.8         NaN       37.5        35.9         No
# 3            82.9         NaN       39.8        35.6         No
# 4            88.1         NaN       36.8        34.8         No

# %%
travel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 12 columns):
# Date              205 non-null object
# StartTime         205 non-null object
# DayOfWeek         205 non-null object
# GoingTo           205 non-null object
# Distance          205 non-null float64
# MaxSpeed          205 non-null float64
# AvgSpeed          205 non-null float64
# AvgMovingSpeed    205 non-null float64
# FuelEconomy       188 non-null object
# TotalTime         205 non-null float64
# MovingTime        205 non-null float64
# Take407All        205 non-null object
# dtypes: float64(6), object(6)
# memory usage: 19.3+ KB

# %%
travel_df['FuelEconomy'] = pd.to_numeric(travel_df['FuelEconomy'],errors='coerce')

# %%
travel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 12 columns):
# Date              205 non-null object
# StartTime         205 non-null object
# DayOfWeek         205 non-null object
# GoingTo           205 non-null object
# Distance          205 non-null float64
# MaxSpeed          205 non-null float64
# AvgSpeed          205 non-null float64
# AvgMovingSpeed    205 non-null float64
# FuelEconomy       186 non-null float64
# TotalTime         205 non-null float64
# MovingTime        205 non-null float64
# Take407All        205 non-null object
# dtypes: float64(7), object(5)
# memory usage: 19.3+ KB

# %%
travel_df['FuelEconomy'].fillna(travel_df['FuelEconomy'].mean(),inplace=True)

# %%
travel_df.head()
# Out:
#        Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0  1/6/2012     16:37     Friday    Home     51.29     127.4      78.3
# 1  1/6/2012     08:20     Friday     GSK     51.63     130.3      81.8
# 2  1/4/2012     16:17  Wednesday    Home     51.27     127.4      82.0
# 3  1/4/2012     07:53  Wednesday     GSK     49.17     132.3      74.2
# 4  1/3/2012     18:57    Tuesday    Home     51.15     136.2      83.4
#
#    AvgMovingSpeed  FuelEconomy  TotalTime  MovingTime Take407All
# 0            84.8     8.690591       39.3        36.3         No
# 1            88.9     8.690591       37.9        34.9         No
# 2            85.8     8.690591       37.5        35.9         No
# 3            82.9     8.690591       39.8        35.6         No
# 4            88.1     8.690591       36.8        34.8         No

# %%
travel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 12 columns):
# Date              205 non-null object
# StartTime         205 non-null object
# DayOfWeek         205 non-null object
# GoingTo           205 non-null object
# Distance          205 non-null float64
# MaxSpeed          205 non-null float64
# AvgSpeed          205 non-null float64
# AvgMovingSpeed    205 non-null float64
# FuelEconomy       205 non-null float64
# TotalTime         205 non-null float64
# MovingTime        205 non-null float64
# Take407All        205 non-null object
# dtypes: float64(7), object(5)
# memory usage: 19.3+ KB

# %%
travel_df_by_date = travel_df.groupby(['Date','DayOfWeek'])
type(travel_df_by_date)
# Out:
# pandas.core.groupby.DataFrameGroupBy

# %%
travel_df_by_date_combined = travel_df_by_date.sum()

# %%
travel_df_by_date_combined.head()
# Out:
#                       Distance  MaxSpeed  AvgSpeed  AvgMovingSpeed  \
# Date       DayOfWeek
# 1/2/2012   Monday       100.38     251.5     160.4           173.2
# 1/3/2012   Tuesday      102.95     272.0     167.9           176.9
# 1/4/2012   Wednesday    100.44     259.7     156.2           168.7
# 1/6/2012   Friday       102.92     257.7     160.1           173.7
# 10/11/2011 Tuesday      100.46     265.9     153.0           171.6
#
#                       FuelEconomy  TotalTime  MovingTime
# Date       DayOfWeek
# 1/2/2012   Monday       17.381183       75.1        69.6
# 1/3/2012   Tuesday      17.381183       73.6        69.8
# 1/4/2012   Wednesday    17.381183       77.3        71.5
# 1/6/2012   Friday       17.381183       77.2        71.2
# 10/11/2011 Tuesday      15.620000       80.3        71.0

# %%
travel_df_by_date_combined['MaxSpeed'] = travel_df_by_date['MaxSpeed'].max()
travel_df_by_date_combined['AvgSpeed'] = travel_df_by_date['AvgSpeed'].mean()
travel_df_by_date_combined['AvgMovingSpeed'] = travel_df_by_date['AvgMovingSpeed'].mean()
travel_df_by_date_combined['FuelEconomy'] = travel_df_by_date['FuelEconomy'].mean()

# %%
travel_df_by_date_combined.head()
# Out:
#                       Distance  MaxSpeed  AvgSpeed  AvgMovingSpeed  \
# Date       DayOfWeek
# 1/2/2012   Monday       100.38     128.3     80.20           86.60
# 1/3/2012   Tuesday      102.95     136.2     83.95           88.45
# 1/4/2012   Wednesday    100.44     132.3     78.10           84.35
# 1/6/2012   Friday       102.92     130.3     80.05           86.85
# 10/11/2011 Tuesday      100.46     135.1     76.50           85.80
#
#                       FuelEconomy  TotalTime  MovingTime
# Date       DayOfWeek
# 1/2/2012   Monday        8.690591       75.1        69.6
# 1/3/2012   Tuesday       8.690591       73.6        69.8
# 1/4/2012   Wednesday     8.690591       77.3        71.5
# 1/6/2012   Friday        8.690591       77.2        71.2
# 10/11/2011 Tuesday       7.810000       80.3        71.0

# %%
travel_df_by_date_combined.tail()
# Out:
#                      Distance  MaxSpeed  AvgSpeed  AvgMovingSpeed  \
# Date      DayOfWeek
# 9/28/2011 Wednesday    101.88     128.8     90.70           93.60
# 9/29/2011 Thursday     102.04     128.4     74.40           79.40
# 9/6/2011  Tuesday      107.24     132.5     95.25           98.15
# 9/7/2011  Wednesday    100.42     132.8     64.00           71.55
# 9/8/2011  Thursday     100.17     137.0     60.20           70.40
#
#                      FuelEconomy  TotalTime  MovingTime
# Date      DayOfWeek
# 9/28/2011 Wednesday         8.93       68.5        66.4
# 9/29/2011 Thursday          8.93       83.6        77.9
# 9/6/2011  Tuesday           8.50       67.6        65.6
# 9/7/2011  Wednesday         8.50       95.2        84.5
# 9/8/2011  Thursday          8.50      100.8        86.2

# %%
travel_df_by_date_combined.iloc[0]
# Out:
# Distance          100.380000
# MaxSpeed          128.300000
# AvgSpeed           80.200000
# AvgMovingSpeed     86.600000
# FuelEconomy         8.690591
# TotalTime          75.100000
# MovingTime         69.600000
# Name: (1/2/2012, Monday), dtype: float64

# %%
travel_df_by_date_combined.iloc[-1]
# Out:
# Distance          100.17
# MaxSpeed          137.00
# AvgSpeed           60.20
# AvgMovingSpeed     70.40
# FuelEconomy         8.50
# TotalTime         100.80
# MovingTime         86.20
# Name: (9/8/2011, Thursday), dtype: float64

# %%
travel_df_by_date_combined.iloc[10]
# Out:
# Distance          103.07
# MaxSpeed          125.20
# AvgSpeed           70.70
# AvgMovingSpeed     79.40
# FuelEconomy         8.75
# TotalTime          87.50
# MovingTime         77.90
# Name: (10/20/2011, Thursday), dtype: float64

# %%
travel_df_by_date_combined.reset_index(inplace=True)

# %%
travel_df_by_date_combined
# Out:
#            Date  DayOfWeek  Distance  MaxSpeed  AvgSpeed  AvgMovingSpeed  \
# 0      1/2/2012     Monday    100.38     128.3     80.20           86.60
# 1      1/3/2012    Tuesday    102.95     136.2     83.95           88.45
# 2      1/4/2012  Wednesday    100.44     132.3     78.10           84.35
# 3      1/6/2012     Friday    102.92     130.3     80.05           86.85
# 4    10/11/2011    Tuesday    100.46     135.1     76.50           85.80
# 5    10/12/2011  Wednesday    101.98     128.4     59.60           66.55
# 6    10/13/2011   Thursday     50.66     128.3    105.50          111.30
# 7    10/17/2011     Monday    101.91     137.1     86.15           91.60
# 8    10/18/2011    Tuesday    103.10     133.1     75.15           82.15
# 9    10/19/2011  Wednesday    102.98     130.2     69.55           77.45
# 10   10/20/2011   Thursday    103.07     125.2     70.70           79.40
# 11   10/21/2011     Friday     50.64     129.0    106.60          112.10
# 12   10/24/2011     Monday     51.06     126.5     71.60           78.60
# 13   10/25/2011    Tuesday    104.62     127.4     68.60           77.20
# 14   10/26/2011  Wednesday     51.75     127.9     74.60           81.70
# 15   10/27/2011   Thursday     51.77     125.6     82.40           89.50
# 16   10/28/2011     Friday     51.28     120.5     83.00           89.50
# 17    10/3/2011     Monday    101.87     127.4     86.15           90.80
# 18   10/31/2011     Monday    101.64     125.0     90.40           95.95
# 19    10/4/2011    Tuesday    101.82     128.8     85.45           91.55
# 20    10/5/2011  Wednesday    101.90     128.5     86.45           91.75
# 21    10/6/2011   Thursday    101.92     126.0     55.90           90.05
# 22    10/7/2011     Friday    101.70     128.3     91.15           98.05
# 19      7.970000       72.4        67.1
# 20      7.970000       73.7        68.9
# 21      7.970000       72.8        69.6
# 22      7.970000       68.0        62.8
# 23      8.320000       43.2        39.1
# 24      9.530000       85.2        78.6
# 25      9.530000      103.7        96.1
# 26      9.530000       93.7        83.0
# 27      9.530000       89.5        80.5
# 28     10.050000       86.1        79.5
# 29      8.320000       83.9        78.7
# ..           ...        ...         ...
# 81      8.540000       84.6        76.2
# 82      8.540000       80.1        74.9
# 83      8.540000       88.8        79.6
# 84      8.540000       76.2        70.8
# 85      8.540000       76.2        70.5
# 86      8.500000       86.6        76.3
# 87      8.480000       84.1        76.8
# 88      8.500000       88.8        80.2
# 89      8.500000       87.6        76.7
# 90      8.480000       84.7        77.1
# 91      8.480000       81.7        74.6
# 92      8.540000       84.0        75.1
# 93      8.540000       91.2        81.1
# 94      8.500000       82.3        75.6
# 95      8.500000       85.4        79.1
# 96      8.500000      100.1        85.3
# 97      8.330000       74.4        68.3
# 98      8.330000       75.1        69.8
# 99      8.330000       86.6        78.2
# 100     8.500000       77.0        68.8
# 101     8.330000       87.0        79.7
# 102     8.330000       87.0        78.2
# 103     8.310000       72.4        68.4
# 104     8.310000       65.7        62.6
# 105     8.310000       79.2        74.9
# 106     8.930000       68.5        66.4
# 107     8.930000       83.6        77.9
# 108     8.500000       67.6        65.6
# 109     8.500000       95.2        84.5
# 110     8.500000      100.8        86.2
#
# [111 rows x 9 columns]

# %%
travel_df_by_date_combined.set_index(['Date'],inplace=True)

# %%
travel_df_by_date_combined
# Out:
#             DayOfWeek  Distance  MaxSpeed  AvgSpeed  AvgMovingSpeed  \
# Date
# 1/2/2012       Monday    100.38     128.3     80.20           86.60
# 1/3/2012      Tuesday    102.95     136.2     83.95           88.45
# 1/4/2012    Wednesday    100.44     132.3     78.10           84.35
# 1/6/2012       Friday    102.92     130.3     80.05           86.85
# 10/11/2011    Tuesday    100.46     135.1     76.50           85.80
# 10/12/2011  Wednesday    101.98     128.4     59.60           66.55
# 10/13/2011   Thursday     50.66     128.3    105.50          111.30
# 10/17/2011     Monday    101.91     137.1     86.15           91.60
# 10/18/2011    Tuesday    103.10     133.1     75.15           82.15
# 10/19/2011  Wednesday    102.98     130.2     69.55           77.45
# 10/20/2011   Thursday    103.07     125.2     70.70           79.40
# 10/21/2011     Friday     50.64     129.0    106.60          112.10
# 10/24/2011     Monday     51.06     126.5     71.60           78.60
# 10/25/2011    Tuesday    104.62     127.4     68.60           77.20
# 10/26/2011  Wednesday     51.75     127.9     74.60           81.70
# 10/27/2011   Thursday     51.77     125.6     82.40           89.50
# 10/28/2011     Friday     51.28     120.5     83.00           89.50
# 10/3/2011      Monday    101.87     127.4     86.15           90.80
# 10/31/2011     Monday    101.64     125.0     90.40           95.95
# 10/4/2011     Tuesday    101.82     128.8     85.45           91.55
# 10/5/2011   Wednesday    101.90     128.5     86.45           91.75
# 10/6/2011    Thursday    101.92     126.0     55.90           90.05
# 10/7/2011      Friday    101.70     128.3     91.15           98.05
# 11/1/2011     Tuesday     51.74     129.7     71.80           79.40
# 10/31/2011     8.320000       69.2        64.3
# 10/4/2011      7.970000       72.4        67.1
# 10/5/2011      7.970000       73.7        68.9
# 10/6/2011      7.970000       72.8        69.6
# 10/7/2011      7.970000       68.0        62.8
# 11/1/2011      8.320000       43.2        39.1
# 11/10/2011     9.530000       85.2        78.6
# 11/14/2011     9.530000      103.7        96.1
# 11/15/2011     9.530000       93.7        83.0
# 11/16/2011     9.530000       89.5        80.5
# 11/17/2011    10.050000       86.1        79.5
# 11/2/2011      8.320000       83.9        78.7
# ...                 ...        ...         ...
# 8/22/2011      8.540000       84.6        76.2
# 8/23/2011      8.540000       80.1        74.9
# 8/24/2011      8.540000       88.8        79.6
# 8/25/2011      8.540000       76.2        70.8
# 8/26/2011      8.540000       76.2        70.5
# 8/29/2011      8.500000       86.6        76.3
# 8/3/2011       8.480000       84.1        76.8
# 8/30/2011      8.500000       88.8        80.2
# 8/31/2011      8.500000       87.6        76.7
# 8/4/2011       8.480000       84.7        77.1
# 8/5/2011       8.480000       81.7        74.6
# 8/8/2011       8.540000       84.0        75.1
# 8/9/2011       8.540000       91.2        81.1
# 9/1/2011       8.500000       82.3        75.6
# 9/12/2011      8.500000       85.4        79.1
# 9/13/2011      8.500000      100.1        85.3
# 9/14/2011      8.330000       74.4        68.3
# 9/15/2011      8.330000       75.1        69.8
# 9/19/2011      8.330000       86.6        78.2
# 9/2/2011       8.500000       77.0        68.8
# 9/20/2011      8.330000       87.0        79.7
# 9/21/2011      8.330000       87.0        78.2
# 9/22/2011      8.310000       72.4        68.4
# 9/26/2011      8.310000       65.7        62.6
# 9/27/2011      8.310000       79.2        74.9
# 9/28/2011      8.930000       68.5        66.4
# 9/29/2011      8.930000       83.6        77.9
# 9/6/2011       8.500000       67.6        65.6
# 9/7/2011       8.500000       95.2        84.5
# 9/8/2011       8.500000      100.8        86.2
#
# [111 rows x 8 columns]

# %%
type(travel_df_by_date_combined)
# Out:
# pandas.core.frame.DataFrame

# %%
distance_above_ninety = travel_df_by_date_combined['Distance']>90
distance_above_ninety
# Out:
# Date
# 1/2/2012       True
# 1/3/2012       True
# 1/4/2012       True
# 1/6/2012       True
# 10/11/2011     True
# 10/12/2011     True
# 10/13/2011    False
# 10/17/2011     True
# 10/18/2011     True
# 10/19/2011     True
# 10/20/2011     True
# 10/21/2011    False
# 10/24/2011    False
# 10/25/2011     True
# 10/26/2011    False
# 10/27/2011    False
# 10/28/2011    False
# 10/3/2011      True
# 10/31/2011     True
# 10/4/2011      True
# 10/5/2011      True
# 10/6/2011      True
# 10/7/2011      True
# 11/1/2011     False
# 11/10/2011     True
# 11/14/2011     True
# 11/15/2011     True
# 11/16/2011     True
# 11/17/2011     True
# 11/2/2011      True
#               ...
# 8/22/2011      True
# 8/23/2011      True
# 8/24/2011      True
# 8/25/2011      True
# 8/26/2011      True
# 8/29/2011      True
# 8/3/2011       True
# 8/30/2011      True
# 8/31/2011      True
# 8/4/2011       True
# 8/5/2011       True
# 8/8/2011       True
# 8/9/2011       True
# 9/1/2011       True
# 9/12/2011      True
# 9/13/2011      True
# 9/27/2011     False
# 9/28/2011     False
# 9/29/2011     False
# 9/6/2011      False
# 9/7/2011      False
# 9/8/2011      False
# Name: Distance, Length: 111, dtype: bool

# %%
ninety_to_hundred_df = travel_df_by_date_combined[distance_above_ninety & distance_below_hundred]
ninety_to_hundred_df
# Out:
#            DayOfWeek  Distance  MaxSpeed  AvgSpeed  AvgMovingSpeed  \
# Date
# 7/25/2011     Monday     99.37     126.6     66.90           78.60
# 7/27/2011  Wednesday     99.80     124.9     69.35           74.85
# 7/29/2011     Friday     99.75     135.6     90.45           94.05
# 8/26/2011     Friday     99.89     132.7     78.70           85.10
#
#            FuelEconomy  TotalTime  MovingTime
# Date
# 7/25/2011         8.45       96.8        75.9
# 7/27/2011         8.45       86.4        80.2
# 7/29/2011         8.45       68.4        65.5
# 8/26/2011         8.54       76.2        70.5

# %%
ninety_to_hundred_df.loc[['8/26/2011'],['Distance','FuelEconomy']]
# Out:
#            Distance  FuelEconomy
# Date
# 8/26/2011     99.89         8.54

# %%
travel_df.groupby(['DayOfWeek']).sum()
# Out:
#            Distance  MaxSpeed  AvgSpeed  AvgMovingSpeed  FuelEconomy  \
# DayOfWeek
# Friday      1375.89    3444.1    2204.8          2374.3   234.201183
# Monday      1981.04    4953.7    2854.7          3174.8   340.032957
# Thursday    2239.72    5631.4    3272.1          3643.6   384.471183
# Tuesday     2454.12    6155.3    3541.5          3882.9   414.212957
# Wednesday   2400.44    5971.8    3394.8          3729.4   408.652957
#
#            TotalTime  MovingTime
# DayOfWeek
# Friday        1023.9       948.1
# Monday        1684.7      1487.7
# Thursday      1811.8      1646.4
# Tuesday       2041.0      1844.5
# Wednesday     2029.0      1837.0

# %%
travel_df.groupby(['DayOfWeek']).max()
# Out:
#                 Date StartTime GoingTo  Distance  MaxSpeed  AvgSpeed  \
# DayOfWeek
# Friday      9/2/2011     20:31    Home     55.57     135.6     107.7
# Monday     9/26/2011     17:38    Home     54.52     137.8     104.4
# Thursday    9/8/2011     17:58    Home     52.42     137.7     106.8
# Tuesday     9/6/2011     18:57    Home     54.36     138.0      95.4
# Wednesday   9/7/2011     18:05    Home     60.32     140.9     103.4
#
#            AvgMovingSpeed  FuelEconomy  TotalTime  MovingTime Take407All
# DayOfWeek
# Friday              112.1         9.76       47.9        43.2        Yes
# Monday              106.2        10.05       82.3        62.4        Yes
# Thursday            111.3        10.05       61.2        48.9        Yes
# Tuesday             102.6         9.53       70.5        59.8        Yes
# Wednesday           108.0         9.76       54.8        48.5        Yes

# %%
travel_df.groupby(['DayOfWeek'])['AvgMovingSpeed'].describe()
# Out:
#            count       mean        std   min    25%    50%    75%    max
# DayOfWeek
# Friday      27.0  87.937037   9.288792  77.1  81.70  86.90  89.95  112.1
# Monday      39.0  81.405128  10.600297  50.3  75.60  82.40  85.80  106.2
# Thursday    44.0  82.809091  10.534082  63.1  77.05  80.85  85.55  111.3
# Tuesday     48.0  80.893750   9.921338  51.5  75.55  81.05  85.65  102.6
# Wednesday   47.0  79.348936   8.801207  65.8  74.10  78.70  81.75  108.0
